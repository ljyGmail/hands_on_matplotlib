# %% [markdown]
# # Single-Line Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [4, 5, 3, 1, 6, 7]
plt.plot(x)
plt.show()

# %%
x = np.arange(25)
plt.plot(x)
plt.show()

# %%
plt.plot(x, [(y**3 + 1) for y in x])
plt.show()

# %%
# same as above
plt.plot(x, x**3 + 1)
plt.show()

# %% [markdown]
# # Multiline Plots

# %%
x = np.arange(7)
print(x)
print(-x**2)
print(-x**3)
print(-2*x)
print(-2**x)
plt.plot(x, -x**2)
plt.plot(x, -x**3)
plt.plot(x, -2*x)
plt.plot(x, -2**x)
plt.show()
# Out:
# [0 1 2 3 4 5 6]
# [  0  -1  -4  -9 -16 -25 -36]
# [   0   -1   -8  -27  -64 -125 -216]
# [  0  -2  -4  -6  -8 -10 -12]
# [ -1  -2  -4  -8 -16 -32 -64]

# %%
# write the same code in a simple way
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.show()

# %%
x = np.array([[3, 2, 5, 6], [7, 4, 1, 5]])
plt.plot(x)
plt.show()

# %%
data = np.random.randn(2, 10)
print(data)
plt.plot([data[0], data[1]])
plt.show()
# Out:
# [[ 5.83565392e-01  5.24370700e-01  5.13264602e-01  1.22708427e+00
#    3.62193358e-01  4.24409621e-01  4.17710491e-01 -2.76332948e+00
#   -2.93155616e-01 -1.02555333e+00]
#  [-7.99602406e-01 -6.98197675e-01 -5.94842834e-01  2.62053051e-01
#   -4.87053902e-01 -2.28937221e-05 -3.79323345e-01  9.69136090e-01
#   -7.01384752e-01  1.76210719e+00]]

# %% [markdown]
# # Grid, Axes, and Labels

# %%
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.grid(True)
plt.savefig('data/ch04/test.png')
plt.show()

# %%
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.grid(True)
print(plt.axis())
plt.show()
# Out:
# (-0.1, 2.1, -8.4, 0.4)

# %%
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.grid(True)
plt.axis([0, 2, -8, 0])
print(plt.axis())
plt.show()
# Out:
# (0.0, 2.0, -8.0, 0.0)

# %%
# write the previous code with functions xlim() and ylim()
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.grid(True)
plt.xlim([0, 2])
plt.ylim([-8, 0])
print(plt.axis())
plt.show()
# Out:
# (0.0, 2.0, -8.0, 0.0)

# %%
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.grid(True)
plt.xlabel('x = np.arange(3)')
plt.xlim([0, 2])
plt.ylabel('y = f(x)')
plt.ylim([-8, 0])
plt.title('Simple Plot Demo')
plt.show()

# %%
x = np.arange(3)
plt.plot(x, -x**2, label='-x**2')
plt.plot(x, -x**3, label='-x**3')
plt.plot(x, -2*x, label='-2*x')
plt.plot(x, -2**x, label='-2**x')
plt.legend()
plt.grid(True)
plt.xlabel('x = np.arange(3)')
plt.xlim([0, 2])
plt.ylabel('y = f(x)')
plt.ylim([-8, 0])
plt.title('Simple Plot Demo')
plt.show()

# %%
# pass the list of strings as argument to the function legend()
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.legend(['-x**2', '-x**3', '-2*x', '-2**x'])
plt.grid(True)
plt.xlim([0, 2])
plt.ylim([-8, 0])
plt.xlabel('x = np.arange(3)')
plt.ylabel('y = f(x)')
plt.title('Simple Polt Demo')
plt.show()

# %%
# change the location of the legend box
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.legend(['-x**2', '-x**3', '-2*x', '-2**x'], loc='lower center')
plt.grid(True)
plt.xlabel('x = np.arange(3)')
plt.xlim([0, 2])
plt.ylabel('y = f(x)')
plt.ylim([-8, 0])
plt.title('Simple Plot Demo')
plt.show()

# %%
x = np.arange(3)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.legend(['-x**2', '-x**3', '-2*x', '-2**x'])
plt.grid(True)
plt.xlabel('x = np.arange(3)')
plt.xlim([0, 2])
plt.ylabel('y = f(x)')
plt.ylim([-8, 0])
plt.title('Simple Plot Demo')
plt.savefig('data/ch04/test2.png')
plt.show()

# %% [markdown]
# # Colors, Styles, and Markers

# %%
x = np.arange(5)
y = x
plt.plot(x, y+0.4, 'g')
plt.plot(x, y+0.2, 'y')
plt.plot(x, y, 'r')
plt.plot(x, y-0.2, 'c')
plt.plot(x, y-0.4, 'k')
plt.plot(x, y-0.6, 'm')
plt.plot(x, y-0.8, 'w')
plt.plot(x, y-1, 'b')
plt.show()

# %%
plt.plot(x, y+0.4, 'g', x, y+0.2, 'y', x, y, 'r', x, y-0.2, 'c', x, y-0.4, 'k', x, y-0.6, 'm', x, y-0.8, 'w', x, y-1, 'b')
plt.show()

# %%
# customize line style
plt.plot(x, y, '-', x, y+1, '--', x, y+2, '-.', x, y+3, ':')
plt.show()

# %%
# change the makers
plt.plot(x, y, '.')
plt.plot(x, y+0.5, ',')
plt.plot(x, y+1, 'o')
plt.plot(x, y+2, '<')
plt.plot(x, y+3, '>')
plt.plot(x, y+4, 'v')
plt.plot(x, y+5, '^')
plt.plot(x, y+6, '1')
plt.plot(x, y+7, '2')
plt.plot(x, y+8, '3')
plt.plot(x, y+9, '4')
plt.plot(x, y+10, 's')
plt.plot(x, y+11, 'p')
plt.plot(x, y+12, '*')
plt.plot(x, y+13, 'h')
plt.plot(x, y+14, 'H')
plt.plot(x, y+15, '+')
plt.plot(x, y+16, 'D')
plt.plot(x, y+17, 'd')
plt.plot(x, y+18, '|')
plt.plot(x, y+19, '_')
plt.show()

# %%
# combine all three techniques (for colors, markers and line styles)
plt.plot(x, y, 'mo--')
plt.plot(x, y+1, 'g*-.')
plt.show()

# %%
# customize everything in great detail
plt.plot(x, y, color='g', linestyle='--', linewidth=1.5,
        marker='^', markerfacecolor='b', markeredgecolor='k',
        markeredgewidth=1.5, markersize=5)
plt.grid(True)
plt.show()

# %%
# customize the values on the x- and y-axes
x = y = np.arange(10)
plt.plot(x, y, 'o--')
plt.xticks(range(len(x)), ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
plt.yticks(range(0, 10, 1))
plt.show()

# %% [markdown]
# # Object-Oriented Plotting

# %%
fig, ax = plt.subplots()
x = np.arange(3)
ax.plot(x, -x**2, label='-x**2')
ax.plot(x, -x**3, label='-x**3')
ax.plot(x, -2*x, label='-2*x')
ax.plot(x, -2**x, label='-2**x')
ax.set_xlabel('x = np.arange(3)')
ax.set_ylabel('y = f(x)')
ax.set_title('Simple Plot Demo')
ax.legend()
ax.grid(True)
plt.show()

# %%
# add text
fig, ax = plt.subplots()
ax.plot(x, -x**2, label='-x**2')
ax.plot(x, -x**3, label='-x**3')
ax.plot(x, -2*x, label='-2*x')
ax.plot(x, -2**x, label='-2**x')
ax.set_xlabel('x = np.arange(3)')
ax.set_ylabel('y = f(x)')
ax.set_title('Simple Plot Demo')
ax.legend()
ax.grid(True)
ax.text(0.25, -5, 'Simple Plot Demo')
plt.show()

# %%
x = np.arange(3)
plt.subplots_adjust(wspace=0.3, hspace=0.3)

plt.subplot(2, 2, 1)
plt.plot(x, -x**2)
plt.subplot(2, 2, 2)
plt.plot(x, -x**3)
plt.subplot(2, 2, 3)
plt.plot(x, -2*x)
plt.subplot(2, 2, 4)
plt.plot(x, -2**x)
plt.show()

# %%
# write the same code in object-oriented fashion
fig, axs = plt.subplots(2, 2)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
axs[0, 0].plot(x, -x**2)
axs[0, 1].plot(x, -x**3)
axs[1, 0].plot(x, -2*x)
axs[1, 1].plot(x, -2**x)
plt.show()
